# %%
# This Python 3 environment comes with many helpful analytics libraries installed
#!/usr/bin/env python3
"""
calibre_ad_plus_full_pipeline.py

Standalone, script form of `alzheimerupdate_version_1.ipynb` — the complete
analysis pipeline behind the paper:

    "CALiBRE-AD+: A Nested, Leakage-Audited, Calibrated, Cost-Sensitive
    Ensemble for Alzheimer's Disease Classification"
    MD Rahat Rihan, American International University-Bangladesh.

This file is a line-for-line extraction of every code cell in the notebook
(cells 0-16, in order), combined into one runnable script. Nothing has been
re-derived or rewritten: the model configs, the nested cross-fitting loop,
the calibration and thresholding logic, the figures, and the final
consolidated summary are exactly what the notebook runs. The notebook
remains the primary, canonical source (and the easiest way to inspect
intermediate outputs cell-by-cell) — this script exists so the same
pipeline can be run non-interactively (`python calibre_ad_plus_full_pipeline.py`),
reviewed as plain Python, or imported as a module.

USAGE
-----
    python3 calibre_ad_plus_full_pipeline.py

REQUIREMENTS
------------
    pip install -r requirements.txt
    (pandas, numpy, scikit-learn, xgboost, lightgbm, catboost, shap,
     matplotlib, seaborn — see this repo's requirements.txt for pinned
     versions matching the paper's Table III)

INPUT
-----
    alzheimers_disease_data_loaded.csv must be present in one of:
      - ./alzheimers_disease_data_loaded.csv
      - /kaggle/input/datasets/rahatrihan/alzheimers-disease-dataset-update/alzheimers_disease_data_loaded.csv
      - data/alzheimers_disease_data_loaded.csv
    Source: R. El Kharoua, "Alzheimer's Disease Dataset," Kaggle, 2024,
    doi: 10.34740/KAGGLE/DSV/8668279 (CC-BY 4.0).

OUTPUT
------
    - Printed tables (Tables III, IV, V, VII) and all console diagnostics
    - figures/fig3_leakage_audit.png ... figures/fig10_shap_importance.png
    - paper_numbers.json — every number reported in the paper, in one file

Runtime: a few minutes on 4 CPU cores (nested 5-outer x 3-inner cross-fitting
over 7 base learners on ~2,000 records; the SHAP cell is the slowest single
step).
"""

import sys
import subprocess
import importlib

# ---------------------------------------------------------------------------
# Cell 2 (part 1) — make sure optional heavy dependencies are present
# ---------------------------------------------------------------------------
for pkg in ["xgboost", "lightgbm", "catboost", "shap"]:
    try:
        importlib.import_module(pkg)
    except ImportError:
        subprocess.run([sys.executable, "-m", "pip", "install", "-q", pkg])

import warnings
import os
import platform
import hashlib
import json

warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib

# Headless-safe: if there's no display (CI, servers, this repro run),
# fall back to the non-interactive Agg backend so plt.show() never hangs
# or errors. This does not change any figure's content.
if not os.environ.get("DISPLAY") and sys.platform != "darwin":
    matplotlib.use("Agg")

import matplotlib.pyplot as plt
import seaborn as sns
from importlib.metadata import version

from sklearn.model_selection import StratifiedKFold
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.svm import SVC
from sklearn.isotonic import IsotonicRegression
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, average_precision_score, brier_score_loss,
    confusion_matrix, matthews_corrcoef, roc_curve,
    precision_recall_curve,
)
from sklearn.calibration import calibration_curve
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from scipy.stats import binomtest

RNG = 42
np.random.seed(RNG)
sns.set_style("whitegrid")
plt.rcParams.update({"figure.dpi": 110, "font.size": 11})

os.makedirs("figures", exist_ok=True)


# ---------------------------------------------------------------------------
# Cell 0 — display helpers
# (banner()/style_table() are cosmetic-only; they render nicely in a
# notebook and degrade gracefully to plain prints in a terminal.)
# ---------------------------------------------------------------------------
try:
    from IPython.display import display, HTML
    _HAVE_IPYTHON_DISPLAY = True
except ImportError:
    _HAVE_IPYTHON_DISPLAY = False

    def display(x):  # minimal fallback so the rest of the script is untouched
        print(x)

    class HTML(str):
        pass

PALETTE = {
    "info": "#2c6fbb",
    "success": "#2e8b57",
    "warn": "#e08a1e",
    "table": "#7d4a9e",
    "result": "#c0392b",
}


def banner(title, kind="info", emoji="\U0001F537"):
    """Colored section banner -- purely cosmetic, no effect on computation."""
    if _HAVE_IPYTHON_DISPLAY:
        color = PALETTE.get(kind, "#2c6fbb")
        display(HTML(
            f'<div style="background:{color};color:white;padding:9px 16px;'
            f'border-radius:8px;font-size:15px;font-weight:600;margin:8px 0;'
            f'font-family:sans-serif;">{emoji}&nbsp; {title}</div>'
        ))
    else:
        print(f"\n=== {title} ===")


def style_table(df, caption=None, cmap="Blues", precision=3):
    """Render a DataFrame as a shaded HTML table (notebook) or plain text (terminal)."""
    if not _HAVE_IPYTHON_DISPLAY:
        if caption:
            print(caption)
        print(df.round(precision))
        return df
    sty = df.style.background_gradient(cmap=cmap, axis=None).format(precision=precision)
    if caption:
        sty = sty.set_caption(caption)
    sty = sty.set_table_styles([
        {"selector": "caption", "props": [("font-size", "14px"), ("font-weight", "bold"),
                                           ("color", "#2c3e50"), ("padding", "6px 0"),
                                           ("caption-side", "top")]},
        {"selector": "th", "props": [("font-size", "12px")]},
        {"selector": "td", "props": [("font-size", "12px"), ("text-align", "center")]},
    ])
    return sty


print("Display helpers ready ✅")


# ---------------------------------------------------------------------------
# Cell 2 (part 2) — TABLE I: hardware / software environment
# ---------------------------------------------------------------------------
banner("TABLE I — Hardware and Software Environment", "info", "\U0001F5A5️")
print(f"{'OS':<20}{platform.platform()}")
print(f"{'CPU count':<20}{os.cpu_count()}")
print(f"{'Python version':<20}{platform.python_version()}")
for lib in ["pandas", "numpy", "scikit-learn", "xgboost", "lightgbm", "catboost"]:
    try:
        print(f"{lib:<20}{version(lib)}")
    except Exception:
        print(f"{lib:<20}NOT INSTALLED")
banner("Environment captured live — no values were hand-typed.", "success", "✅")


# ---------------------------------------------------------------------------
# Cell 3 — load dataset, hash it
# ---------------------------------------------------------------------------
CSV_CANDIDATES = [
    "/kaggle/input/datasets/rahatrihan/alzheimers-disease-dataset-v1/alzheimers_disease_data_loaded.csv",
]
CSV = next((p for p in CSV_CANDIDATES if os.path.exists(p)), None)
if CSV is None:
    raise FileNotFoundError(
        "Put alzheimers_disease_data.csv next to this script "
        "(Kaggle: rabieelkharoua/alzheimers-disease-dataset)")

with open(CSV, "rb") as fh:
    MD5 = hashlib.md5(fh.read()).hexdigest()
df = pd.read_csv(CSV)

banner("Dataset loaded", "success", "\U0001F4C4")
print(f"Source file : {CSV}")
print(f"MD5         : {MD5}          <-- quote this in the paper for reproducibility")
print(f"Shape       : {df.shape[0]} records x {df.shape[1]} attributes")
counts = df["Diagnosis"].value_counts().sort_index()
print(f"Class 0 (No AD): {counts[0]}  ({counts[0]/len(df):.1%})")
print(f"Class 1 (AD)   : {counts[1]}  ({counts[1]/len(df):.1%})")


# ---------------------------------------------------------------------------
# Cell 4 — feature-provenance audit (Full vs. Screening track split)
# ---------------------------------------------------------------------------
banner("Feature-provenance audit", "info", "\U0001F50E")
data = df.drop(columns=["PatientID", "DoctorInCharge"], errors="ignore")
y = data["Diagnosis"].values
X_all = data.drop(columns=["Diagnosis"])

CLINICAL = ["MMSE", "FunctionalAssessment", "ADL", "MemoryComplaints", "BehavioralProblems",
            "Confusion", "Disorientation", "PersonalityChanges",
            "DifficultyCompletingTasks", "Forgetfulness"]
CLINICAL = [c for c in CLINICAL if c in X_all.columns]
SCREENING = [c for c in X_all.columns if c not in CLINICAL]

print(f"Predictors after dropping identifiers : {X_all.shape[1]}")
print(f"Clinical (withheld in Screening track): {len(CLINICAL)} -> {CLINICAL}")
print(f"Screening track features              : {len(SCREENING)}")
assert len(CLINICAL) + len(SCREENING) == X_all.shape[1]


# ---------------------------------------------------------------------------
# Cell 5 — correlation audit
# ---------------------------------------------------------------------------
corr = data.corr(numeric_only=True)["Diagnosis"].drop("Diagnosis")
ranked = corr.reindex(corr.abs().sort_values(ascending=False).index)
banner("Top correlates of Diagnosis", "info", "\U0001F4C8")
print("Top 8 |r| with Diagnosis  (C = clinical, S = screening):")
for feat, r in ranked.head(8).items():
    print(f"  {'C' if feat in CLINICAL else 'S'}  {feat:<28}{r:+.3f}")
top5 = ranked.head(5)
print(f"\nTop-5 all clinical? {all(f in CLINICAL for f in top5.index)}")
print(f"Top-5 |r| range        : {top5.abs().min():.3f} to {top5.abs().max():.3f}")
print(f"Max screening |r|      : {corr[SCREENING].abs().max():.3f} "
      f"({corr[SCREENING].abs().idxmax()})")
print(">> Correct the Section IV-B sentence to these printed values.")


# ---------------------------------------------------------------------------
# Cell 6 — CONFIG + the seven-learner base bank
# ---------------------------------------------------------------------------
CONFIG = {
    "outer_folds": 5, "inner_folds": 3, "seed": RNG,
    "primary_cost_ratio": 5, "cost_ratios": [1, 2, 5, 10],
    "calibration_candidates": ["sigmoid", "isotonic"],
    "calibration_selection_metric": "Brier (inner cross-fitted)",
    "learners": {
        "Elastic-Net LR": dict(C=1.0, l1_ratio=0.5, class_weight="balanced"),
        "RBF-SVM":        dict(C=10, gamma="scale", class_weight="balanced"),
        "Random Forest":  dict(n_estimators=200, max_depth=10, min_samples_leaf=1),
        "Extra Trees":    dict(n_estimators=200, max_depth=10, min_samples_leaf=1),
        "XGBoost":        dict(n_estimators=200, max_depth=3, learning_rate=0.05),
        "LightGBM":       dict(n_estimators=200, num_leaves=15, learning_rate=0.05),
        "CatBoost":       dict(iterations=200, depth=4, learning_rate=0.05),
        "Meta-learner":   dict(penalty="l2", C=1.0, class_weight="balanced"),
    },
}
banner("TABLE II — Training Hyperparameters (from live CONFIG)", "info", "⚙️")
for name, hp in CONFIG["learners"].items():
    print(f"  {name:<16}{hp}")
print(f"  {'CV protocol':<16}outer={CONFIG['outer_folds']}, "
      f"inner={CONFIG['inner_folds']}, seed={CONFIG['seed']}")


def base_bank():
    """The SEVEN learners named in the paper. Values come from CONFIG."""
    L = CONFIG["learners"]
    return {
        "Elastic-Net LR": LogisticRegression(
            penalty="elasticnet", solver="saga", l1_ratio=L["Elastic-Net LR"]["l1_ratio"],
            C=L["Elastic-Net LR"]["C"], class_weight="balanced",
            max_iter=5000, random_state=RNG),
        "RBF-SVM": SVC(
            C=L["RBF-SVM"]["C"], kernel="rbf", gamma="scale", probability=True,
            class_weight="balanced", random_state=RNG),
        "Random Forest": RandomForestClassifier(
            n_estimators=200, max_depth=10, min_samples_leaf=1,
            class_weight="balanced", random_state=RNG, n_jobs=-1),
        "Extra Trees": ExtraTreesClassifier(
            n_estimators=200, max_depth=10, min_samples_leaf=1,
            class_weight="balanced", random_state=RNG, n_jobs=-1),
        "XGBoost": XGBClassifier(
            n_estimators=200, max_depth=3, learning_rate=0.05,
            eval_metric="logloss", random_state=RNG, n_jobs=-1, verbosity=0),
        "LightGBM": LGBMClassifier(
            n_estimators=200, num_leaves=15, learning_rate=0.05,
            random_state=RNG, n_jobs=-1, verbose=-1),
        "CatBoost": CatBoostClassifier(
            iterations=200, depth=4, learning_rate=0.05,
            random_seed=RNG, verbose=0, thread_count=-1),
    }


LEARNER_NAMES = list(base_bank().keys())
assert len(LEARNER_NAMES) == 7, "paper claims seven base learners"


# ---------------------------------------------------------------------------
# Cell 7 — calibration, thresholding, and metric helpers
# ---------------------------------------------------------------------------
def fit_calibrator(kind, s, yy):
    """Return a callable mapping raw stacked scores -> calibrated probabilities."""
    if kind == "sigmoid":                       # Platt scaling (Eq. 3-style logistic map)
        lr = LogisticRegression(C=1e10, solver="lbfgs", max_iter=1000)
        lr.fit(s.reshape(-1, 1), yy)
        return lambda t: lr.predict_proba(np.asarray(t).reshape(-1, 1))[:, 1]
    iso = IsotonicRegression(out_of_bounds="clip", y_min=0.0, y_max=1.0)   # Eq. 4, PAVA
    iso.fit(s, yy)
    return lambda t: np.asarray(iso.predict(np.asarray(t)))


GRID = np.round(np.arange(0.005, 1.0, 0.005), 4)


def cost_threshold(yy, p, fn_cost, fp_cost=1.0):
    """Eq. 6: tau* = argmin  fn_cost*FN + fp_cost*FP.  Called on TRAIN data only."""
    best_t, best_c = 0.5, np.inf
    for t in GRID:
        tn, fp, fn, tp = confusion_matrix(yy, (p >= t).astype(int), labels=[0, 1]).ravel()
        c = fn_cost * fn + fp_cost * fp
        if c < best_c:
            best_c, best_t = c, t
    return float(best_t)


def metrics(yy, proba, pred):
    return {
        "Acc": accuracy_score(yy, pred),
        "Pr": precision_score(yy, pred, zero_division=0),
        "Rc": recall_score(yy, pred, zero_division=0),
        "F1": f1_score(yy, pred, zero_division=0),
        "AUC": roc_auc_score(yy, proba),
        "PR-AUC": average_precision_score(yy, proba),
        "MCC": matthews_corrcoef(yy, pred),
        "Brr": brier_score_loss(yy, proba),
    }


# ---------------------------------------------------------------------------
# Cell 8 — the nested cross-fitting pipeline (the core of the paper)
# ---------------------------------------------------------------------------
def nested_run(X, yy, track_name):
    """
    5 stratified OUTER folds. Inside each outer-training fold ONLY:
      imputer, scaler, 7 base learners, inner-OOF meta-features,
      logistic meta-learner, calibrator selection, cost thresholds.
    The outer test fold is touched exactly once, at prediction time.
    Returns pooled out-of-fold artefacts for every table in the paper.
    """
    X = np.asarray(X, dtype=float)
    n = len(yy)
    outer = StratifiedKFold(CONFIG["outer_folds"], shuffle=True, random_state=RNG)
    inner = StratifiedKFold(CONFIG["inner_folds"], shuffle=True, random_state=RNG)

    base_proba = {m: np.zeros(n) for m in LEARNER_NAMES}   # Table III / IV rows
    meta_raw = np.zeros(n)                                  # stack, uncalibrated
    meta_cal = np.zeros(n)                                  # stack, calibrated
    tau = {c: np.zeros(n) for c in CONFIG["cost_ratios"]}   # per-record fold threshold
    fold_log = []

    for k, (tr, te) in enumerate(outer.split(X, yy), start=1):
        Xtr_raw, Xte_raw, ytr = X[tr], X[te], yy[tr]

        imp = SimpleImputer(strategy="median").fit(Xtr_raw)
        sca = StandardScaler().fit(imp.transform(Xtr_raw))
        Xtr = sca.transform(imp.transform(Xtr_raw))
        Xte = sca.transform(imp.transform(Xte_raw))

        # --- Stage 2/3: inner cross-fitting -> OOF meta-features Z_tr -----------
        Z_tr = np.zeros((len(tr), 7))
        Z_te = np.zeros((len(te), 7))
        for j, name in enumerate(LEARNER_NAMES):
            for itr, ite in inner.split(Xtr, ytr):
                mdl = base_bank()[name]
                mdl.fit(Xtr[itr], ytr[itr])
                Z_tr[ite, j] = mdl.predict_proba(Xtr[ite])[:, 1]
            full = base_bank()[name]            # refit on the whole outer-training fold
            full.fit(Xtr, ytr)
            Z_te[:, j] = full.predict_proba(Xte)[:, 1]
            base_proba[name][te] = Z_te[:, j]   # single-learner rows use the same folds

        meta = LogisticRegression(penalty="l2", C=1.0, class_weight="balanced",
                                  max_iter=5000, random_state=RNG)
        meta.fit(Z_tr, ytr)
        s_te = meta.predict_proba(Z_te)[:, 1]
        meta_raw[te] = s_te

        # --- second cross-fitting layer: honest meta scores on TRAIN -----------
        s_tr = np.zeros(len(tr))
        for itr, ite in inner.split(Z_tr, ytr):
            m2 = LogisticRegression(penalty="l2", C=1.0, class_weight="balanced",
                                    max_iter=5000, random_state=RNG)
            m2.fit(Z_tr[itr], ytr[itr])
            s_tr[ite] = m2.predict_proba(Z_tr[ite])[:, 1]

        # --- Stage 4a: ADAPTIVE calibration, chosen by inner-cross-fitted Brier -
        scores = {}
        for kind in CONFIG["calibration_candidates"]:
            oof_cal = np.zeros(len(tr))
            for itr, ite in inner.split(s_tr.reshape(-1, 1), ytr):
                g = fit_calibrator(kind, s_tr[itr], ytr[itr])
                oof_cal[ite] = g(s_tr[ite])
            scores[kind] = brier_score_loss(ytr, np.clip(oof_cal, 0, 1))
        chosen = min(scores, key=scores.get)
        g_final = fit_calibrator(chosen, s_tr, ytr)
        meta_cal[te] = np.clip(g_final(s_te), 0, 1)
        p_tr_cal = np.clip(g_final(s_tr), 0, 1)     # train-only, for thresholding

        # --- Stage 4b: cost thresholds, TRAIN ONLY (this is the leakage fix) ----
        taus = {c: cost_threshold(ytr, p_tr_cal, float(c)) for c in CONFIG["cost_ratios"]}
        for c in CONFIG["cost_ratios"]:
            tau[c][te] = taus[c]

        fold_log.append({"fold": k, "n_train": len(tr), "n_test": len(te),
                         "calibrator": chosen,
                         "brier_sigmoid": round(scores["sigmoid"], 5),
                         "brier_isotonic": round(scores["isotonic"], 5),
                         "tau_5to1": taus[5]})
        print(f"  [{track_name}] fold {k}/5  calibrator={chosen:<9} "
              f"brier(sig={scores['sigmoid']:.4f}, iso={scores['isotonic']:.4f})  "
              f"tau@5:1={taus[5]:.3f}")

    return {"base_proba": base_proba, "meta_raw": meta_raw, "meta_cal": meta_cal,
            "tau": tau, "fold_log": pd.DataFrame(fold_log)}


banner("Running FULL track (32 features) — this takes a few minutes...", "warn", "⏳")
FULL = nested_run(X_all.values, y, "FULL")
banner("Running SCREENING track (22 features)...", "warn", "⏳")
SCR = nested_run(X_all[SCREENING].values, y, "SCREENING")


# ---------------------------------------------------------------------------
# Cell 9 — calibrator choice per track
# ---------------------------------------------------------------------------
banner("Calibrator choice per track", "info", "\U0001F3AF")
for tag, R in [("Full", FULL), ("Screening", SCR)]:
    tally = R["fold_log"]["calibrator"].value_counts().to_dict()
    print(f"{tag} track calibrator selection across 5 folds: {tally}")
print(">> Correct the Section V-C sentence to these counts.")
print("\nPer-fold thresholds (Full track, 5:1):",
      [round(t, 3) for t in FULL["fold_log"]["tau_5to1"]])
print("Mean primary operating threshold:",
      round(float(FULL["fold_log"]["tau_5to1"].mean()), 3))


# ---------------------------------------------------------------------------
# Cell 10 — Tables III & IV (Full / Screening performance)
# ---------------------------------------------------------------------------
def build_table(R, primary=5):
    rows = {}
    for name in LEARNER_NAMES:
        p = R["base_proba"][name]
        rows[name] = metrics(y, p, (p >= 0.5).astype(int))   # single learners @0.5
    p = R["meta_cal"]
    pred = (p >= R["tau"][primary]).astype(int)              # ours @ fold-specific tau
    rows["CALiBRE-AD+"] = metrics(y, p, pred)
    return pd.DataFrame(rows).T.round(3)


T3 = build_table(FULL)
T4 = build_table(SCR)[["Acc", "F1", "AUC", "MCC"]]
banner("TABLE III — Full-Track Performance (nested 5-fold out-of-fold)", "table", "\U0001F4CB")
display(style_table(T3, cmap="Blues"))

banner("TABLE IV — Screening-Track Performance (no clinical features)", "table", "\U0001F4CB")
display(style_table(T4, cmap="Oranges"))


# ---------------------------------------------------------------------------
# Cell 11 — Table V (cost-ratio sensitivity) + consistency guard
# ---------------------------------------------------------------------------
rows = {}
for c in CONFIG["cost_ratios"]:
    p = FULL["meta_cal"]
    pred = (p >= FULL["tau"][c]).astype(int)
    m = metrics(y, p, pred)
    rows[f"{c}:1"] = {k: m[k] for k in ["Acc", "Rc", "F1", "MCC"]}
T5 = pd.DataFrame(rows).T.round(3)
banner("TABLE V — Full-Track Cost-Ratio Sensitivity Analysis", "table", "\U0001F4CB")
display(style_table(T5, cmap="Purples"))

# CONSISTENCY GUARD: the 5:1 row must equal the CALiBRE-AD+ row of Table III
for col in ["Acc", "Rc", "F1", "MCC"]:
    assert abs(T5.loc["5:1", col] - T3.loc["CALiBRE-AD+", col]) < 1e-9, \
        f"Table V 5:1 disagrees with Table III on {col} — this was the draft's bug"
banner("Consistency check passed: Table V (5:1) == Table III (CALiBRE-AD+)", "success", "✅")


# ---------------------------------------------------------------------------
# Cell 12 — Table VII (component ablation) + consistency guard
# ---------------------------------------------------------------------------
best_single = T3.drop(index="CALiBRE-AD+")["Acc"].idxmax()
banner("Component ablation", "info", "\U0001F9E9")
print(f"Best single base learner by accuracy: {best_single}")

abl = {}
p = FULL["base_proba"][best_single]
abl[f"Best single base learner ({best_single})"] = metrics(y, p, (p >= 0.5).astype(int))
p = FULL["meta_raw"]
abl["+ Heterogeneous stacking (no calibration)"] = metrics(y, p, (p >= 0.5).astype(int))
p = FULL["meta_cal"]
abl["+ Adaptive calibration (tau = 0.5)"] = metrics(y, p, (p >= 0.5).astype(int))
abl["+ Cost-optimal threshold (CALiBRE-AD+)"] = metrics(
    y, p, (p >= FULL["tau"][5]).astype(int))
T7 = pd.DataFrame(abl).T[["Acc", "AUC", "Brr", "Rc"]].round(3)
banner("TABLE VII — Ablation Study (Full Track)", "table", "\U0001F4CB")
display(style_table(T7, cmap="Greens"))

# CONSISTENCY GUARD: ablation row 1 must equal that learner's Table III row
for col in ["Acc", "AUC", "Brr", "Rc"]:
    assert abs(T7.iloc[0][col] - T3.loc[best_single, col]) < 1e-9
banner("Consistency check passed: ablation row 1 == Table III row.", "success", "✅")

# EXTRA ablation the draft never ran: does expanding 4 -> 7 learners help?
print("\nOptional extra ablation (4 original learners vs 7): "
      "rerun nested_run with LEARNER_NAMES trimmed to "
      "['RBF-SVM','Extra Trees','XGBoost','LightGBM'] and report both rows.")


# ---------------------------------------------------------------------------
# Cell 13 — bootstrap CIs + exact McNemar tests
# ---------------------------------------------------------------------------
banner("Bootstrap confidence intervals", "info", "\U0001F4D0")


def bootstrap_ci(yy, proba, pred, n_boot=2000):
    rng = np.random.default_rng(RNG)
    idx = np.arange(len(yy))
    accs, aucs = [], []
    for _ in range(n_boot):
        s = rng.choice(idx, len(idx), replace=True)
        accs.append((pred[s] == yy[s]).mean())
        if len(np.unique(yy[s])) > 1:
            aucs.append(roc_auc_score(yy[s], proba[s]))
    q = lambda a: (float(np.percentile(a, 2.5)), float(np.percentile(a, 97.5)))
    return q(accs), q(aucs)


ours_p = FULL["meta_cal"]
ours_pred = (ours_p >= FULL["tau"][5]).astype(int)
acc_ci, auc_ci = bootstrap_ci(y, ours_p, ours_pred)
print(f"Accuracy 95% bootstrap CI : [{acc_ci[0]:.3f}, {acc_ci[1]:.3f}]")
print(f"ROC-AUC  95% bootstrap CI : [{auc_ci[0]:.3f}, {auc_ci[1]:.3f}]")


def exact_mcnemar(yy, a, b):
    """Exact (binomial) McNemar test on discordant pairs. Say 'exact' in the paper."""
    ca, cb = (a == yy), (b == yy)
    n01, n10 = int(np.sum(ca & ~cb)), int(np.sum(~ca & cb))
    tot = n01 + n10
    p = 1.0 if tot == 0 else binomtest(min(n01, n10), tot, 0.5).pvalue
    return n01, n10, float(p)


banner("Exact McNemar significance tests", "info", "\U0001F9EA")
for comp in ["CatBoost", "LightGBM"]:
    cp = (FULL["base_proba"][comp] >= 0.5).astype(int)
    n01, n10, pv = exact_mcnemar(y, ours_pred, cp)
    print(f"Exact McNemar vs {comp:<10}: discordant {n01}/{n10}, p={pv:.4f}")


# ---------------------------------------------------------------------------
# Cell 14 — Figures 3-8
# ---------------------------------------------------------------------------
banner("Rendering Figures 3–8", "info", "\U0001F4CA")
models = LEARNER_NAMES + ["CALiBRE-AD+"]
fa = [T3.loc[m, "AUC"] for m in models]
sa = [build_table(SCR).loc[m, "AUC"] for m in models]
x = np.arange(len(models)); w = 0.38
plt.figure(figsize=(12, 5))
plt.bar(x - w/2, fa, w, label="Full", color="#2c6fbb")
plt.bar(x + w/2, sa, w, label="Screening-only", color="#e08a1e")
plt.axhline(0.5, color="#c0392b", ls="--", lw=1)
plt.xticks(x, models, rotation=40, ha="right"); plt.ylabel("ROC-AUC"); plt.ylim(0.4, 1.0)
plt.title("Fig. 3 — Leakage audit"); plt.legend(); plt.tight_layout()
plt.savefig("figures/fig3_leakage_audit.png", dpi=200, bbox_inches="tight")
plt.show()

plt.figure(figsize=(6.5, 5.5))
for p, lab, c in [(FULL["meta_raw"], "Raw stack", "#2c6fbb"),
                  (FULL["meta_cal"], "Calibrated CALiBRE-AD+", "#e08a1e")]:
    ft, mp = calibration_curve(y, p, n_bins=10, strategy="quantile")
    plt.plot(mp, ft, "o-", color=c, label=f"{lab} (Brier={brier_score_loss(y, p):.3f})")
plt.plot([0, 1], [0, 1], "--", color="gray", label="Perfect")
plt.xlabel("Mean predicted probability"); plt.ylabel("Observed frequency")
plt.title("Fig. 4 — Reliability diagram"); plt.legend(); plt.tight_layout()
plt.savefig("figures/fig4_reliability.png", dpi=200, bbox_inches="tight")
plt.show()

ts = GRID
costs = [confusion_matrix(y, (ours_p >= t).astype(int), labels=[0, 1]).ravel() for t in ts]
costs = [5 * fn + fp for tn, fp, fn, tp in costs]
plt.figure(figsize=(7, 4.6))
plt.plot(ts, costs, color="#7d4a9e", lw=2)
mean_tau = float(FULL["fold_log"]["tau_5to1"].mean())
plt.axvline(mean_tau, color="#c0392b", ls="--", label=f"Mean nested threshold={mean_tau:.3f}")
plt.xlabel("Decision threshold"); plt.ylabel("Cost (5·FN + FP)")
plt.title("Fig. 5 — Cost-sensitive threshold selection")
plt.legend(); plt.tight_layout()
plt.savefig("figures/fig5_cost_threshold.png", dpi=200, bbox_inches="tight")
plt.show()

fig, ax = plt.subplots(1, 2, figsize=(13, 5))
for name, c in [("XGBoost", "#4c72b0"), ("LightGBM", "#dd8452"),
                ("CatBoost", "#55a868"), ("CALiBRE-AD+", "#c44e52")]:
    p = ours_p if name == "CALiBRE-AD+" else FULL["base_proba"][name]
    fpr, tpr, _ = roc_curve(y, p)
    ax[0].plot(fpr, tpr, color=c, lw=2, label=f"{name} ({roc_auc_score(y, p):.3f})")
    pr, rc, _ = precision_recall_curve(y, p)
    ax[1].plot(rc, pr, color=c, lw=2, label=name)
ax[0].plot([0, 1], [0, 1], "--", color="gray"); ax[0].set_title("Fig. 6 — ROC (Full track)")
ax[0].set_xlabel("False positive rate"); ax[0].set_ylabel("True positive rate"); ax[0].legend()
ax[1].set_title("Fig. 7 — Precision-Recall (Full track)")
ax[1].set_xlabel("Recall"); ax[1].set_ylabel("Precision"); ax[1].legend()
plt.tight_layout()
fig.savefig("figures/fig6_roc.png", dpi=200, bbox_inches="tight")
fig.savefig("figures/fig7_pr.png", dpi=200, bbox_inches="tight")
plt.show()

cm = confusion_matrix(y, ours_pred, labels=[0, 1])
plt.figure(figsize=(5.5, 4.6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=["No AD", "AD"], yticklabels=["No AD", "AD"])
plt.xlabel("Predicted"); plt.ylabel("Actual")
plt.title("Fig. 8 — CALiBRE-AD+ confusion matrix (fold-specific tau)")
plt.tight_layout()
plt.savefig("figures/fig8_confusion.png", dpi=200, bbox_inches="tight")
plt.show()
print("Confusion matrix [[TN, FP], [FN, TP]] =", cm.tolist())


# ---------------------------------------------------------------------------
# Cell 15 — Figures 9-10 (SHAP)
# ---------------------------------------------------------------------------
banner("Computing SHAP values (LightGBM, Full track)", "info", "\U0001F50D")
try:
    import shap
    from matplotlib.patches import Patch
    sm = LGBMClassifier(n_estimators=200, num_leaves=15, learning_rate=0.05,
                        random_state=RNG, verbose=-1).fit(X_all, y)
    sv = shap.TreeExplainer(sm).shap_values(X_all)
    if isinstance(sv, list):
        sv = sv[1]
    shap.summary_plot(sv, X_all, max_display=20, show=False)
    plt.savefig("figures/fig9_shap_summary.png", dpi=200, bbox_inches="tight")
    plt.show()
    imp = np.abs(sv).mean(0)
    order = np.argsort(imp)[::-1]
    print("SHAP ranking (top 6) — CORRECT Section VII-D to this order:")
    for i in order[:6]:
        print(f"  {X_all.columns[i]:<28}{imp[i]:.3f}")
    top15 = order[:15]
    names = [X_all.columns[i] for i in top15]
    cols = ["#c0392b" if n in CLINICAL else "#2c6fbb" for n in names]
    plt.figure(figsize=(8, 5.5))
    plt.barh(range(15)[::-1], [imp[i] for i in top15], color=cols)
    plt.yticks(range(15)[::-1], names); plt.xlabel("mean |SHAP value|")
    plt.legend(handles=[Patch(color="#c0392b", label="Clinical assessment"),
                        Patch(color="#2c6fbb", label="Screening")], loc="lower right")
    plt.title("Fig. 10 — Mean |SHAP| importance"); plt.tight_layout()
    plt.savefig("figures/fig10_shap_importance.png", dpi=200, bbox_inches="tight")
    plt.show()
except Exception as e:
    print("SHAP skipped:", e)


# ---------------------------------------------------------------------------
# Cell 16 — consolidated, machine-readable summary of every reported number
# ---------------------------------------------------------------------------
banner("Every number reported in the paper — produced live", "result", "\U0001F4E6")
print(f"Data      | {len(df)} records, {X_all.shape[1]} predictors, "
      f"{counts[0]} neg / {counts[1]} pos, md5={MD5[:8]}")
print(f"Sec IV-B  | top-5 |r| {top5.abs().min():.3f}-{top5.abs().max():.3f} (all clinical), "
      f"max screening |r| = {corr[SCREENING].abs().max():.3f}")
banner("TABLE III (Full track)", "table", "\U0001F4CB"); display(style_table(T3, cmap="Blues"))
banner("TABLE IV (Screening track)", "table", "\U0001F4CB"); display(style_table(T4, cmap="Oranges"))
banner("TABLE V (cost-ratio sensitivity)", "table", "\U0001F4CB"); display(style_table(T5, cmap="Purples"))
banner("TABLE VII (ablation)", "table", "\U0001F4CB"); display(style_table(T7, cmap="Greens"))
o = T3.loc["CALiBRE-AD+"]
print(f"\nAbstract  | Acc {o['Acc']:.3f}  Rc {o['Rc']:.3f}  AUC {o['AUC']:.3f}  "
      f"Brier {o['Brr']:.3f}")
print(f"Abstract  | Acc 95% CI [{acc_ci[0]:.3f}, {acc_ci[1]:.3f}]  "
      f"AUC 95% CI [{auc_ci[0]:.3f}, {auc_ci[1]:.3f}]")
print(f"Abstract  | Screening AUC {T4.loc['CALiBRE-AD+', 'AUC']:.3f}, "
      f"MCC {T4.loc['CALiBRE-AD+', 'MCC']:.3f}")
print(f"Sec VII-A | mean tau = {mean_tau:.3f}; per-fold "
      f"{[round(t, 3) for t in FULL['fold_log']['tau_5to1']]}")
print(f"Sec VII-C | Brier raw {brier_score_loss(y, FULL['meta_raw']):.4f} -> "
      f"calibrated {brier_score_loss(y, FULL['meta_cal']):.4f}")
print(f"Sec V-C   | calibrator choice Full "
      f"{FULL['fold_log']['calibrator'].value_counts().to_dict()}, Screening "
      f"{SCR['fold_log']['calibrator'].value_counts().to_dict()}")
print(f"Fig 8     | confusion matrix {cm.tolist()}")

json.dump({"table3": T3.to_dict(), "table4": T4.to_dict(), "table5": T5.to_dict(),
           "table7": T7.to_dict(), "acc_ci": acc_ci, "auc_ci": auc_ci,
           "mean_tau": mean_tau, "cm": cm.tolist(), "md5": MD5},
          open("paper_numbers.json", "w"), indent=2)
banner("Saved paper_numbers.json — everything above is reproducible from this file.", "success", "✅")
# Out:
# Display helpers ready ✅
# <div style="background:#2c6fbb;color:white;padding:9px 16px;border-radius:8px;font-size:15px;font-weight:600;margin:8px 0;font-family:sans-serif;">🖥️&nbsp; TABLE I — Hardware and Software Environment</div>
# OS                  Linux-6.12.90+-x86_64-with-glibc2.35
# CPU count           4
# Python version      3.12.13
# pandas              2.3.3
# numpy               2.0.2
# scikit-learn        1.6.1
# xgboost             3.2.0
# lightgbm            4.6.0
# catboost            1.2.10
# <div style="background:#2e8b57;color:white;padding:9px 16px;border-radius:8px;font-size:15px;font-weight:600;margin:8px 0;font-family:sans-serif;">✅&nbsp; Environment captured live — no values were hand-typed.</div>
# <div style="background:#2e8b57;color:white;padding:9px 16px;border-radius:8px;font-size:15px;font-weight:600;margin:8px 0;font-family:sans-serif;">📄&nbsp; Dataset loaded</div>
# Source file : /kaggle/input/datasets/rahatrihan/alzheimers-disease-dataset-v1/alzheimers_disease_data_loaded.csv
# MD5         : f01b1f4197fb211a0eb9d9e5f5495efa          <-- quote this in the paper for reproducibility
# Shape       : 2149 records x 35 attributes
# Class 0 (No AD): 1389  (64.6%)
# Class 1 (AD)   : 760  (35.4%)
# <div style="background:#2c6fbb;color:white;padding:9px 16px;border-radius:8px;font-size:15px;font-weight:600;margin:8px 0;font-family:sans-serif;">🔎&nbsp; Feature-provenance audit</div>
# Predictors after dropping identifiers : 32
# Clinical (withheld in Screening track): 10 -> ['MMSE', 'FunctionalAssessment', 'ADL', 'MemoryComplaints', 'BehavioralProblems', 'Confusion', 'Disorientation', 'PersonalityChanges', 'DifficultyCompletingTasks', 'Forgetfulness']
# Screening track features              : 22
# <div style="background:#2c6fbb;color:white;padding:9px 16px;border-radius:8px;font-size:15px;font-weight:600;margin:8px 0;font-family:sans-serif;">📈&nbsp; Top correlates of Diagnosis</div>
# Top 8 |r| with Diagnosis  (C = clinical, S = screening):
#   C  FunctionalAssessment        -0.365
#   C  ADL                         -0.332
#   C  MemoryComplaints            +0.307
#   C  MMSE                        -0.237
#   C  BehavioralProblems          +0.224
#   S  SleepQuality                -0.057
#   S  EducationLevel              -0.044
#   S  CholesterolHDL              +0.043
#
# Top-5 all clinical? True
# Top-5 |r| range        : 0.224 to 0.365
# Max screening |r|      : 0.057 (SleepQuality)
# >> Correct the Section IV-B sentence to these printed values.
# <div style="background:#2c6fbb;color:white;padding:9px 16px;border-radius:8px;font-size:15px;font-weight:600;margin:8px 0;font-family:sans-serif;">⚙️&nbsp; TABLE II — Training Hyperparameters (from live CONFIG)</div>
#   Elastic-Net LR  {'C': 1.0, 'l1_ratio': 0.5, 'class_weight': 'balanced'}
#   RBF-SVM         {'C': 10, 'gamma': 'scale', 'class_weight': 'balanced'}
#   Random Forest   {'n_estimators': 200, 'max_depth': 10, 'min_samples_leaf': 1}
#   Extra Trees     {'n_estimators': 200, 'max_depth': 10, 'min_samples_leaf': 1}
#   XGBoost         {'n_estimators': 200, 'max_depth': 3, 'learning_rate': 0.05}
#   LightGBM        {'n_estimators': 200, 'num_leaves': 15, 'learning_rate': 0.05}
#   CatBoost        {'iterations': 200, 'depth': 4, 'learning_rate': 0.05}
#   Meta-learner    {'penalty': 'l2', 'C': 1.0, 'class_weight': 'balanced'}
#   CV protocol     outer=5, inner=3, seed=42
# <div style="background:#e08a1e;color:white;padding:9px 16px;border-radius:8px;font-size:15px;font-weight:600;margin:8px 0;font-family:sans-serif;">⏳&nbsp; Running FULL track (32 features) — this takes a few minutes...</div>
#   [FULL] fold 1/5  calibrator=isotonic  brier(sig=0.0474, iso=0.0470)  tau@5:1=0.075
#   [FULL] fold 2/5  calibrator=sigmoid   brier(sig=0.0451, iso=0.0483)  tau@5:1=0.240
#   [FULL] fold 3/5  calibrator=sigmoid   brier(sig=0.0428, iso=0.0436)  tau@5:1=0.165
#   [FULL] fold 4/5  calibrator=sigmoid   brier(sig=0.0479, iso=0.0494)  tau@5:1=0.205
#   [FULL] fold 5/5  calibrator=isotonic  brier(sig=0.0441, iso=0.0439)  tau@5:1=0.130
# <div style="background:#e08a1e;color:white;padding:9px 16px;border-radius:8px;font-size:15px;font-weight:600;margin:8px 0;font-family:sans-serif;">⏳&nbsp; Running SCREENING track (22 features)...</div>
#   [SCREENING] fold 1/5  calibrator=sigmoid   brier(sig=0.2287, iso=0.2319)  tau@5:1=0.005
#   [SCREENING] fold 2/5  calibrator=sigmoid   brier(sig=0.2286, iso=0.2296)  tau@5:1=0.005
#   [SCREENING] fold 3/5  calibrator=sigmoid   brier(sig=0.2286, iso=0.2304)  tau@5:1=0.350
#   [SCREENING] fold 4/5  calibrator=sigmoid   brier(sig=0.2285, iso=0.2289)  tau@5:1=0.310
#   [SCREENING] fold 5/5  calibrator=sigmoid   brier(sig=0.2285, iso=0.2300)  tau@5:1=0.315
# <div style="background:#2c6fbb;color:white;padding:9px 16px;border-radius:8px;font-size:15px;font-weight:600;margin:8px 0;font-family:sans-serif;">🎯&nbsp; Calibrator choice per track</div>
# Full track calibrator selection across 5 folds: {'sigmoid': 3, 'isotonic': 2}
# Screening track calibrator selection across 5 folds: {'sigmoid': 5}
# >> Correct the Section V-C sentence to these counts.
#
# Per-fold thresholds (Full track, 5:1): [0.075, 0.24, 0.165, 0.205, 0.13]
# Mean primary operating threshold: 0.163
# <div style="background:#7d4a9e;color:white;padding:9px 16px;border-radius:8px;font-size:15px;font-weight:600;margin:8px 0;font-family:sans-serif;">📋&nbsp; TABLE III — Full-Track Performance (nested 5-fold out-of-fold)</div>
# <style type="text/css">
# #T_299b5 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding: 6px 0;
#   caption-side: top;
# }
# #T_299b5 th {
#   font-size: 12px;
# }
# #T_299b5 td {
#   font-size: 12px;
#   text-align: center;
# }
# #T_299b5_row0_col0, #T_299b5_row1_col0, #T_299b5_row3_col2 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_299b5_row0_col1 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_299b5_row0_col2 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_299b5_row0_col3 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_299b5_row0_col4, #T_299b5_row5_col6, #T_299b5_row6_col6 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_299b5_row0_col5 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_299b5_row0_col6 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_299b5_row0_col7, #T_299b5_row1_col7 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_299b5_row1_col1 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_299b5_row1_col2 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_299b5_row1_col3 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_299b5_row1_col4, #T_299b5_row2_col2 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_299b5_row1_col5 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_299b5_row1_col6 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_299b5_row2_col0 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_299b5_row2_col1, #T_299b5_row4_col1 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_299b5_row2_col3 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_299b5_row2_col4, #T_299b5_row4_col4, #T_299b5_row5_col1, #T_299b5_row6_col1, #T_299b5_row6_col4, #T_299b5_row7_col0, #T_299b5_row7_col4 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_299b5_row2_col5, #T_299b5_row3_col4, #T_299b5_row7_col2, #T_299b5_row7_col5 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_299b5_row2_col6 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_299b5_row2_col7 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_299b5_row3_col0 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_299b5_row3_col1 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_299b5_row3_col3 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_299b5_row3_col5 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_299b5_row3_col6 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_299b5_row3_col7 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_299b5_row4_col0, #T_299b5_row5_col0, #T_299b5_row5_col4, #T_299b5_row6_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_299b5_row4_col2 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_299b5_row4_col3, #T_299b5_row7_col3 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_299b5_row4_col5, #T_299b5_row6_col5 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_299b5_row4_col6 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_299b5_row4_col7 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_299b5_row5_col2, #T_299b5_row6_col2 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_299b5_row5_col3, #T_299b5_row5_col5, #T_299b5_row6_col3, #T_299b5_row7_col1 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_299b5_row5_col7, #T_299b5_row7_col7 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_299b5_row6_col7 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_299b5_row7_col6 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_299b5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_299b5_level0_col0" class="col_heading level0 col0" >Acc</th>
#       <th id="T_299b5_level0_col1" class="col_heading level0 col1" >Pr</th>
#       <th id="T_299b5_level0_col2" class="col_heading level0 col2" >Rc</th>
#       <th id="T_299b5_level0_col3" class="col_heading level0 col3" >F1</th>
#       <th id="T_299b5_level0_col4" class="col_heading level0 col4" >AUC</th>
#       <th id="T_299b5_level0_col5" class="col_heading level0 col5" >PR-AUC</th>
#       <th id="T_299b5_level0_col6" class="col_heading level0 col6" >MCC</th>
#       <th id="T_299b5_level0_col7" class="col_heading level0 col7" >Brr</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_299b5_level0_row0" class="row_heading level0 row0" >Elastic-Net LR</th>
#       <td id="T_299b5_row0_col0" class="data row0 col0" >0.819</td>
#       <td id="T_299b5_row0_col1" class="data row0 col1" >0.713</td>
#       <td id="T_299b5_row0_col2" class="data row0 col2" >0.814</td>
#       <td id="T_299b5_row0_col3" class="data row0 col3" >0.760</td>
#       <td id="T_299b5_row0_col4" class="data row0 col4" >0.898</td>
#       <td id="T_299b5_row0_col5" class="data row0 col5" >0.837</td>
#       <td id="T_299b5_row0_col6" class="data row0 col6" >0.619</td>
#       <td id="T_299b5_row0_col7" class="data row0 col7" >0.127</td>
#     </tr>
#     <tr>
#       <th id="T_299b5_level0_row1" class="row_heading level0 row1" >RBF-SVM</th>
#       <td id="T_299b5_row1_col0" class="data row1 col0" >0.819</td>
#       <td id="T_299b5_row1_col1" class="data row1 col1" >0.776</td>
#       <td id="T_299b5_row1_col2" class="data row1 col2" >0.684</td>
#       <td id="T_299b5_row1_col3" class="data row1 col3" >0.727</td>
#       <td id="T_299b5_row1_col4" class="data row1 col4" >0.884</td>
#       <td id="T_299b5_row1_col5" class="data row1 col5" >0.823</td>
#       <td id="T_299b5_row1_col6" class="data row1 col6" >0.595</td>
#       <td id="T_299b5_row1_col7" class="data row1 col7" >0.127</td>
#     </tr>
#     <tr>
#       <th id="T_299b5_level0_row2" class="row_heading level0 row2" >Random Forest</th>
#       <td id="T_299b5_row2_col0" class="data row2 col0" >0.941</td>
#       <td id="T_299b5_row2_col1" class="data row2 col1" >0.945</td>
#       <td id="T_299b5_row2_col2" class="data row2 col2" >0.884</td>
#       <td id="T_299b5_row2_col3" class="data row2 col3" >0.914</td>
#       <td id="T_299b5_row2_col4" class="data row2 col4" >0.950</td>
#       <td id="T_299b5_row2_col5" class="data row2 col5" >0.930</td>
#       <td id="T_299b5_row2_col6" class="data row2 col6" >0.870</td>
#       <td id="T_299b5_row2_col7" class="data row2 col7" >0.086</td>
#     </tr>
#     <tr>
#       <th id="T_299b5_level0_row3" class="row_heading level0 row3" >Extra Trees</th>
#       <td id="T_299b5_row3_col0" class="data row3 col0" >0.883</td>
#       <td id="T_299b5_row3_col1" class="data row3 col1" >0.846</td>
#       <td id="T_299b5_row3_col2" class="data row3 col2" >0.817</td>
#       <td id="T_299b5_row3_col3" class="data row3 col3" >0.831</td>
#       <td id="T_299b5_row3_col4" class="data row3 col4" >0.929</td>
#       <td id="T_299b5_row3_col5" class="data row3 col5" >0.889</td>
#       <td id="T_299b5_row3_col6" class="data row3 col6" >0.742</td>
#       <td id="T_299b5_row3_col7" class="data row3 col7" >0.135</td>
#     </tr>
#     <tr>
#       <th id="T_299b5_level0_row4" class="row_heading level0 row4" >XGBoost</th>
#       <td id="T_299b5_row4_col0" class="data row4 col0" >0.953</td>
#       <td id="T_299b5_row4_col1" class="data row4 col1" >0.947</td>
#       <td id="T_299b5_row4_col2" class="data row4 col2" >0.917</td>
#       <td id="T_299b5_row4_col3" class="data row4 col3" >0.932</td>
#       <td id="T_299b5_row4_col4" class="data row4 col4" >0.950</td>
#       <td id="T_299b5_row4_col5" class="data row4 col5" >0.940</td>
#       <td id="T_299b5_row4_col6" class="data row4 col6" >0.896</td>
#       <td id="T_299b5_row4_col7" class="data row4 col7" >0.051</td>
#     </tr>
#     <tr>
#       <th id="T_299b5_level0_row5" class="row_heading level0 row5" >LightGBM</th>
#       <td id="T_299b5_row5_col0" class="data row5 col0" >0.955</td>
#       <td id="T_299b5_row5_col1" class="data row5 col1" >0.949</td>
#       <td id="T_299b5_row5_col2" class="data row5 col2" >0.922</td>
#       <td id="T_299b5_row5_col3" class="data row5 col3" >0.935</td>
#       <td id="T_299b5_row5_col4" class="data row5 col4" >0.952</td>
#       <td id="T_299b5_row5_col5" class="data row5 col5" >0.936</td>
#       <td id="T_299b5_row5_col6" class="data row5 col6" >0.901</td>
#       <td id="T_299b5_row5_col7" class="da
# <div style="background:#7d4a9e;color:white;padding:9px 16px;border-radius:8px;font-size:15px;font-weight:600;margin:8px 0;font-family:sans-serif;">📋&nbsp; TABLE IV — Screening-Track Performance (no clinical features)</div>
# <style type="text/css">
# #T_f7067 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding: 6px 0;
#   caption-side: top;
# }
# #T_f7067 th {
#   font-size: 12px;
# }
# #T_f7067 td {
#   font-size: 12px;
#   text-align: center;
# }
# #T_f7067_row0_col0, #T_f7067_row0_col2 {
#   background-color: #b93d02;
#   color: #f1f1f1;
# }
# #T_f7067_row0_col1 {
#   background-color: #e35608;
#   color: #f1f1f1;
# }
# #T_f7067_row0_col3 {
#   background-color: #fee7d1;
#   color: #000000;
# }
# #T_f7067_row1_col0 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_f7067_row1_col1, #T_f7067_row1_col3, #T_f7067_row7_col3 {
#   background-color: #fff2e6;
#   color: #000000;
# }
# #T_f7067_row1_col2 {
#   background-color: #d14501;
#   color: #f1f1f1;
# }
# #T_f7067_row2_col0 {
#   background-color: #8c2c04;
#   color: #f1f1f1;
# }
# #T_f7067_row2_col1 {
#   background-color: #fdbe84;
#   color: #000000;
# }
# #T_f7067_row2_col2 {
#   background-color: #c64102;
#   color: #f1f1f1;
# }
# #T_f7067_row2_col3 {
#   background-color: #ffefdf;
#   color: #000000;
# }
# #T_f7067_row3_col0 {
#   background-color: #932f03;
#   color: #f1f1f1;
# }
# #T_f7067_row3_col1 {
#   background-color: #fd9f56;
#   color: #000000;
# }
# #T_f7067_row3_col2 {
#   background-color: #c34002;
#   color: #f1f1f1;
# }
# #T_f7067_row3_col3 {
#   background-color: #feecda;
#   color: #000000;
# }
# #T_f7067_row4_col0 {
#   background-color: #8a2b04;
#   color: #f1f1f1;
# }
# #T_f7067_row4_col1 {
#   background-color: #fddab6;
#   color: #000000;
# }
# #T_f7067_row4_col2 {
#   background-color: #d94801;
#   color: #f1f1f1;
# }
# #T_f7067_row4_col3 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_f7067_row5_col0 {
#   background-color: #942f03;
#   color: #f1f1f1;
# }
# #T_f7067_row5_col1 {
#   background-color: #fdc088;
#   color: #000000;
# }
# #T_f7067_row5_col2 {
#   background-color: #d54601;
#   color: #f1f1f1;
# }
# #T_f7067_row5_col3 {
#   background-color: #fff5ea;
#   color: #000000;
# }
# #T_f7067_row6_col0 {
#   background-color: #802704;
#   color: #f1f1f1;
# }
# #T_f7067_row6_col1 {
#   background-color: #fee5cb;
#   color: #000000;
# }
# #T_f7067_row6_col2 {
#   background-color: #cd4401;
#   color: #f1f1f1;
# }
# #T_f7067_row6_col3 {
#   background-color: #ffeedd;
#   color: #000000;
# }
# #T_f7067_row7_col0 {
#   background-color: #f77b28;
#   color: #f1f1f1;
# }
# #T_f7067_row7_col1 {
#   background-color: #be3f02;
#   color: #f1f1f1;
# }
# #T_f7067_row7_col2 {
#   background-color: #d34601;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f7067">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f7067_level0_col0" class="col_heading level0 col0" >Acc</th>
#       <th id="T_f7067_level0_col1" class="col_heading level0 col1" >F1</th>
#       <th id="T_f7067_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_f7067_level0_col3" class="col_heading level0 col3" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f7067_level0_row0" class="row_heading level0 row0" >Elastic-Net LR</th>
#       <td id="T_f7067_row0_col0" class="data row0 col0" >0.531</td>
#       <td id="T_f7067_row0_col1" class="data row0 col1" >0.445</td>
#       <td id="T_f7067_row0_col2" class="data row0 col2" >0.530</td>
#       <td id="T_f7067_row0_col3" class="data row0 col3" >0.060</td>
#     </tr>
#     <tr>
#       <th id="T_f7067_level0_row1" class="row_heading level0 row1" >RBF-SVM</th>
#       <td id="T_f7067_row1_col0" class="data row1 col0" >0.646</td>
#       <td id="T_f7067_row1_col1" class="data row1 col1" >0.000</td>
#       <td id="T_f7067_row1_col2" class="data row1 col2" >0.493</td>
#       <td id="T_f7067_row1_col3" class="data row1 col3" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_f7067_level0_row2" class="row_heading level0 row2" >Random Forest</th>
#       <td id="T_f7067_row2_col0" class="data row2 col0" >0.617</td>
#       <td id="T_f7067_row2_col1" class="data row2 col1" >0.195</td>
#       <td id="T_f7067_row2_col2" class="data row2 col2" >0.509</td>
#       <td id="T_f7067_row2_col3" class="data row2 col3" >0.020</td>
#     </tr>
#     <tr>
#       <th id="T_f7067_level0_row3" class="row_heading level0 row3" >Extra Trees</th>
#       <td id="T_f7067_row3_col0" class="data row3 col0" >0.604</td>
#       <td id="T_f7067_row3_col1" class="data row3 col1" >0.271</td>
#       <td id="T_f7067_row3_col2" class="data row3 col2" >0.515</td>
#       <td id="T_f7067_row3_col3" class="data row3 col3" >0.034</td>
#     </tr>
#     <tr>
#       <th id="T_f7067_level0_row4" class="row_heading level0 row4" >XGBoost</th>
#       <td id="T_f7067_row4_col0" class="data row4 col0" >0.621</td>
#       <td id="T_f7067_row4_col1" class="data row4 col1" >0.111</td>
#       <td id="T_f7067_row4_col2" class="data row4 col2" >0.479</td>
#       <td id="T_f7067_row4_col3" class="data row4 col3" >-0.016</td>
#     </tr>
#     <tr>
#       <th id="T_f7067_level0_row5" class="row_heading level0 row5" >LightGBM</th>
#       <td id="T_f7067_row5_col0" class="data row5 col0" >0.602</td>
#       <td id="T_f7067_row5_col1" class="data row5 col1" >0.190</td>
#       <td id="T_f7067_row5_col2" class="data row5 col2" >0.488</td>
#       <td id="T_f7067_row5_col3" class="data row5 col3" >-0.012</td>
#     </tr>
#     <tr>
#       <th id="T_f7067_level0_row6" class="row_heading level0 row6" >CatBoost</th>
#       <td id="T_f7067_row6_col0" class="data row6 col0" >0.641</td>
#       <td id="T_f7067_row6_col1" class="data row6 col1" >0.072</td>
#       <td id="T_f7067_row6_col2" class="data row6 col2" >0.500</td>
#       <td id="T_f7067_row6_col3" class="data row6 col3" >0.025</td>
#     </tr>
#     <tr>
#       <th id="T_f7067_level0_row7" class="row_heading level0 row7" >CALiBRE-AD+</th>
#       <td id="T_f7067_row7_col0" class="data row7 col0" >0.354</td>
#       <td id="T_f7067_row7_col1" class="data row7 col1" >0.523</td>
#       <td id="T_f7067_row7_col2" class="data row7 col2" >0.490</td>
#       <td id="T_f7067_row7_col3" class="data row7 col3" >0.000</td>
#     </tr>
#   </tbody>
# </table>
# <div style="background:#7d4a9e;color:white;padding:9px 16px;border-radius:8px;font-size:15px;font-weight:600;margin:8px 0;font-family:sans-serif;">📋&nbsp; TABLE V — Full-Track Cost-Ratio Sensitivity Analysis</div>
# <style type="text/css">
# #T_ee100 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding: 6px 0;
#   caption-side: top;
# }
# #T_ee100 th {
#   font-size: 12px;
# }
# #T_ee100 td {
#   font-size: 12px;
#   text-align: center;
# }
# #T_ee100_row0_col0, #T_ee100_row1_col0 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_ee100_row0_col1, #T_ee100_row1_col1 {
#   background-color: #8784bd;
#   color: #f1f1f1;
# }
# #T_ee100_row0_col2 {
#   background-color: #6c55a5;
#   color: #f1f1f1;
# }
# #T_ee100_row0_col3 {
#   background-color: #dcdcec;
#   color: #000000;
# }
# #T_ee100_row1_col2 {
#   background-color: #715faa;
#   color: #f1f1f1;
# }
# #T_ee100_row1_col3 {
#   background-color: #e1e0ee;
#   color: #000000;
# }
# #T_ee100_row2_col0 {
#   background-color: #440981;
#   color: #f1f1f1;
# }
# #T_ee100_row2_col1, #T_ee100_row3_col1 {
#   background-color: #7b72b4;
#   color: #f1f1f1;
# }
# #T_ee100_row2_col2 {
#   background-color: #7465ad;
#   color: #f1f1f1;
# }
# #T_ee100_row2_col3 {
#   background-color: #e8e7f2;
#   color: #000000;
# }
# #T_ee100_row3_col0 {
#   background-color: #4f1d8b;
#   color: #f1f1f1;
# }
# #T_ee100_row3_col2 {
#   background-color: #8a86bf;
#   color: #f1f1f1;
# }
# #T_ee100_row3_col3 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_ee100">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ee100_level0_col0" class="col_heading level0 col0" >Acc</th>
#       <th id="T_ee100_level0_col1" class="col_heading level0 col1" >Rc</th>
#       <th id="T_ee100_level0_col2" class="col_heading level0 col2" >F1</th>
#       <th id="T_ee100_level0_col3" class="col_heading level0 col3" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee100_level0_row0" class="row_heading level0 row0" >1:1</th>
#       <td id="T_ee100_row0_col0" class="data row0 col0" >0.953</td>
#       <td id="T_ee100_row0_col1" class="data row0 col1" >0.924</td>
#       <td id="T_ee100_row0_col2" class="data row0 col2" >0.934</td>
#       <td id="T_ee100_row0_col3" class="data row0 col3" >0.898</td>
#     </tr>
#     <tr>
#       <th id="T_ee100_level0_row1" class="row_heading level0 row1" >2:1</th>
#       <td id="T_ee100_row1_col0" class="data row1 col0" >0.953</td>
#       <td id="T_ee100_row1_col1" class="data row1 col1" >0.924</td>
#       <td id="T_ee100_row1_col2" class="data row1 col2" >0.932</td>
#       <td id="T_ee100_row1_col3" class="data row1 col3" >0.896</td>
#     </tr>
#     <tr>
#       <th id="T_ee100_level0_row2" class="row_heading level0 row2" >5:1</th>
#       <td id="T_ee100_row2_col0" class="data row2 col0" >0.951</td>
#       <td id="T_ee100_row2_col1" class="data row2 col1" >0.928</td>
#       <td id="T_ee100_row2_col2" class="data row2 col2" >0.931</td>
#       <td id="T_ee100_row2_col3" class="data row2 col3" >0.893</td>
#     </tr>
#     <tr>
#       <th id="T_ee100_level0_row3" class="row_heading level0 row3" >10:1</th>
#       <td id="T_ee100_row3_col0" class="data row3 col0" >0.946</td>
#       <td id="T_ee100_row3_col1" class="data row3 col1" >0.928</td>
#       <td id="T_ee100_row3_col2" class="data row3 col2" >0.923</td>
#       <td id="T_ee100_row3_col3" class="data row3 col3" >0.881</td>
#     </tr>
#   </tbody>
# </table>
# <div style="background:#2e8b57;color:white;padding:9px 16px;border-radius:8px;font-size:15px;font-weight:600;margin:8px 0;font-family:sans-serif;">✅&nbsp; Consistency check passed: Table V (5:1) == Table III (CALiBRE-AD+)</div>
# <div style="background:#2c6fbb;color:white;padding:9px 16px;border-radius:8px;font-size:15px;font-weight:600;margin:8px 0;font-family:sans-serif;">🧩&nbsp; Component ablation</div>
# Best single base learner by accuracy: LightGBM
# <div style="background:#7d4a9e;color:white;padding:9px 16px;border-radius:8px;font-size:15px;font-weight:600;margin:8px 0;font-family:sans-serif;">📋&nbsp; TABLE VII — Ablation Study (Full Track)</div>
# <style type="text/css">
# #T_80593 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding: 6px 0;
#   caption-side: top;
# }
# #T_80593 th {
#   font-size: 12px;
# }
# #T_80593 td {
#   font-size: 12px;
#   text-align: center;
# }
# #T_80593_row0_col0, #T_80593_row0_col1, #T_80593_row1_col0, #T_80593_row2_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_80593_row0_col2, #T_80593_row1_col2, #T_80593_row2_col2, #T_80593_row3_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_80593_row0_col3 {
#   background-color: #005020;
#   color: #f1f1f1;
# }
# #T_80593_row1_col1, #T_80593_row2_col1, #T_80593_row3_col0, #T_80593_row3_col1 {
#   background-color: #00451c;
#   color: #f1f1f1;
# }
# #T_80593_row1_col3, #T_80593_row2_col3 {
#   background-color: #004e1f;
#   color: #f1f1f1;
# }
# #T_80593_row3_col3 {
#   background-color: #004d1f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_80593">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80593_level0_col0" class="col_heading level0 col0" >Acc</th>
#       <th id="T_80593_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_80593_level0_col2" class="col_heading level0 col2" >Brr</th>
#       <th id="T_80593_level0_col3" class="col_heading level0 col3" >Rc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80593_level0_row0" class="row_heading level0 row0" >Best single base learner (LightGBM)</th>
#       <td id="T_80593_row0_col0" class="data row0 col0" >0.955</td>
#       <td id="T_80593_row0_col1" class="data row0 col1" >0.952</td>
#       <td id="T_80593_row0_col2" class="data row0 col2" >0.045</td>
#       <td id="T_80593_row0_col3" class="data row0 col3" >0.922</td>
#     </tr>
#     <tr>
#       <th id="T_80593_level0_row1" class="row_heading level0 row1" >+ Heterogeneous stacking (no calibration)</th>
#       <td id="T_80593_row1_col0" class="data row1 col0" >0.955</td>
#       <td id="T_80593_row1_col1" class="data row1 col1" >0.950</td>
#       <td id="T_80593_row1_col2" class="data row1 col2" >0.045</td>
#       <td id="T_80593_row1_col3" class="data row1 col3" >0.926</td>
#     </tr>
#     <tr>
#       <th id="T_80593_level0_row2" class="row_heading level0 row2" >+ Adaptive calibration (tau = 0.5)</th>
#       <td id="T_80593_row2_col0" class="data row2 col0" >0.953</td>
#       <td id="T_80593_row2_col1" class="data row2 col1" >0.948</td>
#       <td id="T_80593_row2_col2" class="data row2 col2" >0.043</td>
#       <td id="T_80593_row2_col3" class="data row2 col3" >0.924</td>
#     </tr>
#     <tr>
#       <th id="T_80593_level0_row3" class="row_heading level0 row3" >+ Cost-optimal threshold (CALiBRE-AD+)</th>
#       <td id="T_80593_row3_col0" class="data row3 col0" >0.951</td>
#       <td id="T_80593_row3_col1" class="data row3 col1" >0.948</td>
#       <td id="T_80593_row3_col2" class="data row3 col2" >0.043</td>
#       <td id="T_80593_row3_col3" class="data row3 col3" >0.928</td>
#     </tr>
#   </tbody>
# </table>
# <div style="background:#2e8b57;color:white;padding:9px 16px;border-radius:8px;font-size:15px;font-weight:600;margin:8px 0;font-family:sans-serif;">✅&nbsp; Consistency check passed: ablation row 1 == Table III row.</div>
# Optional extra ablation (4 original learners vs 7): rerun nested_run with LEARNER_NAMES trimmed to ['RBF-SVM','Extra Trees','XGBoost','LightGBM'] and report both rows.
# <div style="background:#2c6fbb;color:white;padding:9px 16px;border-radius:8px;font-size:15px;font-weight:600;margin:8px 0;font-family:sans-serif;">📐&nbsp; Bootstrap confidence intervals</div>
# Accuracy 95% bootstrap CI : [0.941, 0.960]
# ROC-AUC  95% bootstrap CI : [0.935, 0.960]
# <div style="background:#2c6fbb;color:white;padding:9px 16px;border-radius:8px;font-size:15px;font-weight:600;margin:8px 0;font-family:sans-serif;">🧪&nbsp; Exact McNemar significance tests</div>
# Exact McNemar vs CatBoost  : discordant 4/12, p=0.0768
# Exact McNemar vs LightGBM  : discordant 4/12, p=0.0768
# <div style="background:#2c6fbb;color:white;padding:9px 16px;border-radius:8px;font-size:15px;font-weight:600;margin:8px 0;font-family:sans-serif;">📊&nbsp; Rendering Figures 3–8</div>
# Confusion matrix [[TN, FP], [FN, TP]] = [[1339, 50], [55, 705]]
# <div style="background:#2c6fbb;color:white;padding:9px 16px;border-radius:8px;font-size:15px;font-weight:600;margin:8px 0;font-family:sans-serif;">🔍&nbsp; Computing SHAP values (LightGBM, Full track)</div>
# SHAP ranking (top 6) — CORRECT Section VII-D to this order:
#   FunctionalAssessment        1.498
#   ADL                         1.329
#   MMSE                        1.003
#   MemoryComplaints            0.973
#   BehavioralProblems          0.704
#   CholesterolTotal            0.159
# <div style="background:#c0392b;color:white;padding:9px 16px;border-radius:8px;font-size:15px;font-weight:600;margin:8px 0;font-family:sans-serif;">📦&nbsp; Every number reported in the paper — produced live</div>
# Data      | 2149 records, 32 predictors, 1389 neg / 760 pos, md5=f01b1f41
# Sec IV-B  | top-5 |r| 0.224-0.365 (all clinical), max screening |r| = 0.057
# <div style="background:#7d4a9e;color:white;padding:9px 16px;border-radius:8px;font-size:15px;font-weight:600;margin:8px 0;font-family:sans-serif;">📋&nbsp; TABLE III (Full track)</div>
# <style type="text/css">
# #T_b4409 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding: 6px 0;
#   caption-side: top;
# }
# #T_b4409 th {
#   font-size: 12px;
# }
# #T_b4409 td {
#   font-size: 12px;
#   text-align: center;
# }
# #T_b4409_row0_col0, #T_b4409_row1_col0, #T_b4409_row3_col2 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_b4409_row0_col1 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_b4409_row0_col2 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_b4409_row0_col3 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_b4409_row0_col4, #T_b4409_row5_col6, #T_b4409_row6_col6 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_b4409_row0_col5 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_b4409_row0_col6 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_b4409_row0_col7, #T_b4409_row1_col7 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_b4409_row1_col1 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_b4409_row1_col2 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_b4409_row1_col3 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_b4409_row1_col4, #T_b4409_row2_col2 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_b4409_row1_col5 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_b4409_row1_col6 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_b4409_row2_col0 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_b4409_row2_col1, #T_b4409_row4_col1 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_b4409_row2_col3 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_b4409_row2_col4, #T_b4409_row4_col4, #T_b4409_row5_col1, #T_b4409_row6_col1, #T_b4409_row6_col4, #T_b4409_row7_col0, #T_b4409_row7_col4 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_b4409_row2_col5, #T_b4409_row3_col4, #T_b4409_row7_col2, #T_b4409_row7_col5 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_b4409_row2_col6 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_b4409_row2_col7 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_b4409_row3_col0 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_b4409_row3_col1 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_b4409_row3_col3 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_b4409_row3_col5 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_b4409_row3_col6 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_b4409_row3_col7 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_b4409_row4_col0, #T_b4409_row5_col0, #T_b4409_row5_col4, #T_b4409_row6_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_b4409_row4_col2 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_b4409_row4_col3, #T_b4409_row7_col3 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_b4409_row4_col5, #T_b4409_row6_col5 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_b4409_row4_col6 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_b4409_row4_col7 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_b4409_row5_col2, #T_b4409_row6_col2 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_b4409_row5_col3, #T_b4409_row5_col5, #T_b4409_row6_col3, #T_b4409_row7_col1 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_b4409_row5_col7, #T_b4409_row7_col7 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_b4409_row6_col7 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_b4409_row7_col6 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b4409">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4409_level0_col0" class="col_heading level0 col0" >Acc</th>
#       <th id="T_b4409_level0_col1" class="col_heading level0 col1" >Pr</th>
#       <th id="T_b4409_level0_col2" class="col_heading level0 col2" >Rc</th>
#       <th id="T_b4409_level0_col3" class="col_heading level0 col3" >F1</th>
#       <th id="T_b4409_level0_col4" class="col_heading level0 col4" >AUC</th>
#       <th id="T_b4409_level0_col5" class="col_heading level0 col5" >PR-AUC</th>
#       <th id="T_b4409_level0_col6" class="col_heading level0 col6" >MCC</th>
#       <th id="T_b4409_level0_col7" class="col_heading level0 col7" >Brr</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4409_level0_row0" class="row_heading level0 row0" >Elastic-Net LR</th>
#       <td id="T_b4409_row0_col0" class="data row0 col0" >0.819</td>
#       <td id="T_b4409_row0_col1" class="data row0 col1" >0.713</td>
#       <td id="T_b4409_row0_col2" class="data row0 col2" >0.814</td>
#       <td id="T_b4409_row0_col3" class="data row0 col3" >0.760</td>
#       <td id="T_b4409_row0_col4" class="data row0 col4" >0.898</td>
#       <td id="T_b4409_row0_col5" class="data row0 col5" >0.837</td>
#       <td id="T_b4409_row0_col6" class="data row0 col6" >0.619</td>
#       <td id="T_b4409_row0_col7" class="data row0 col7" >0.127</td>
#     </tr>
#     <tr>
#       <th id="T_b4409_level0_row1" class="row_heading level0 row1" >RBF-SVM</th>
#       <td id="T_b4409_row1_col0" class="data row1 col0" >0.819</td>
#       <td id="T_b4409_row1_col1" class="data row1 col1" >0.776</td>
#       <td id="T_b4409_row1_col2" class="data row1 col2" >0.684</td>
#       <td id="T_b4409_row1_col3" class="data row1 col3" >0.727</td>
#       <td id="T_b4409_row1_col4" class="data row1 col4" >0.884</td>
#       <td id="T_b4409_row1_col5" class="data row1 col5" >0.823</td>
#       <td id="T_b4409_row1_col6" class="data row1 col6" >0.595</td>
#       <td id="T_b4409_row1_col7" class="data row1 col7" >0.127</td>
#     </tr>
#     <tr>
#       <th id="T_b4409_level0_row2" class="row_heading level0 row2" >Random Forest</th>
#       <td id="T_b4409_row2_col0" class="data row2 col0" >0.941</td>
#       <td id="T_b4409_row2_col1" class="data row2 col1" >0.945</td>
#       <td id="T_b4409_row2_col2" class="data row2 col2" >0.884</td>
#       <td id="T_b4409_row2_col3" class="data row2 col3" >0.914</td>
#       <td id="T_b4409_row2_col4" class="data row2 col4" >0.950</td>
#       <td id="T_b4409_row2_col5" class="data row2 col5" >0.930</td>
#       <td id="T_b4409_row2_col6" class="data row2 col6" >0.870</td>
#       <td id="T_b4409_row2_col7" class="data row2 col7" >0.086</td>
#     </tr>
#     <tr>
#       <th id="T_b4409_level0_row3" class="row_heading level0 row3" >Extra Trees</th>
#       <td id="T_b4409_row3_col0" class="data row3 col0" >0.883</td>
#       <td id="T_b4409_row3_col1" class="data row3 col1" >0.846</td>
#       <td id="T_b4409_row3_col2" class="data row3 col2" >0.817</td>
#       <td id="T_b4409_row3_col3" class="data row3 col3" >0.831</td>
#       <td id="T_b4409_row3_col4" class="data row3 col4" >0.929</td>
#       <td id="T_b4409_row3_col5" class="data row3 col5" >0.889</td>
#       <td id="T_b4409_row3_col6" class="data row3 col6" >0.742</td>
#       <td id="T_b4409_row3_col7" class="data row3 col7" >0.135</td>
#     </tr>
#     <tr>
#       <th id="T_b4409_level0_row4" class="row_heading level0 row4" >XGBoost</th>
#       <td id="T_b4409_row4_col0" class="data row4 col0" >0.953</td>
#       <td id="T_b4409_row4_col1" class="data row4 col1" >0.947</td>
#       <td id="T_b4409_row4_col2" class="data row4 col2" >0.917</td>
#       <td id="T_b4409_row4_col3" class="data row4 col3" >0.932</td>
#       <td id="T_b4409_row4_col4" class="data row4 col4" >0.950</td>
#       <td id="T_b4409_row4_col5" class="data row4 col5" >0.940</td>
#       <td id="T_b4409_row4_col6" class="data row4 col6" >0.896</td>
#       <td id="T_b4409_row4_col7" class="data row4 col7" >0.051</td>
#     </tr>
#     <tr>
#       <th id="T_b4409_level0_row5" class="row_heading level0 row5" >LightGBM</th>
#       <td id="T_b4409_row5_col0" class="data row5 col0" >0.955</td>
#       <td id="T_b4409_row5_col1" class="data row5 col1" >0.949</td>
#       <td id="T_b4409_row5_col2" class="data row5 col2" >0.922</td>
#       <td id="T_b4409_row5_col3" class="data row5 col3" >0.935</td>
#       <td id="T_b4409_row5_col4" class="data row5 col4" >0.952</td>
#       <td id="T_b4409_row5_col5" class="data row5 col5" >0.936</td>
#       <td id="T_b4409_row5_col6" class="data row5 col6" >0.901</td>
#       <td id="T_b4409_row5_col7" class="da
# <div style="background:#7d4a9e;color:white;padding:9px 16px;border-radius:8px;font-size:15px;font-weight:600;margin:8px 0;font-family:sans-serif;">📋&nbsp; TABLE IV (Screening track)</div>
# <style type="text/css">
# #T_208b4 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding: 6px 0;
#   caption-side: top;
# }
# #T_208b4 th {
#   font-size: 12px;
# }
# #T_208b4 td {
#   font-size: 12px;
#   text-align: center;
# }
# #T_208b4_row0_col0, #T_208b4_row0_col2 {
#   background-color: #b93d02;
#   color: #f1f1f1;
# }
# #T_208b4_row0_col1 {
#   background-color: #e35608;
#   color: #f1f1f1;
# }
# #T_208b4_row0_col3 {
#   background-color: #fee7d1;
#   color: #000000;
# }
# #T_208b4_row1_col0 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_208b4_row1_col1, #T_208b4_row1_col3, #T_208b4_row7_col3 {
#   background-color: #fff2e6;
#   color: #000000;
# }
# #T_208b4_row1_col2 {
#   background-color: #d14501;
#   color: #f1f1f1;
# }
# #T_208b4_row2_col0 {
#   background-color: #8c2c04;
#   color: #f1f1f1;
# }
# #T_208b4_row2_col1 {
#   background-color: #fdbe84;
#   color: #000000;
# }
# #T_208b4_row2_col2 {
#   background-color: #c64102;
#   color: #f1f1f1;
# }
# #T_208b4_row2_col3 {
#   background-color: #ffefdf;
#   color: #000000;
# }
# #T_208b4_row3_col0 {
#   background-color: #932f03;
#   color: #f1f1f1;
# }
# #T_208b4_row3_col1 {
#   background-color: #fd9f56;
#   color: #000000;
# }
# #T_208b4_row3_col2 {
#   background-color: #c34002;
#   color: #f1f1f1;
# }
# #T_208b4_row3_col3 {
#   background-color: #feecda;
#   color: #000000;
# }
# #T_208b4_row4_col0 {
#   background-color: #8a2b04;
#   color: #f1f1f1;
# }
# #T_208b4_row4_col1 {
#   background-color: #fddab6;
#   color: #000000;
# }
# #T_208b4_row4_col2 {
#   background-color: #d94801;
#   color: #f1f1f1;
# }
# #T_208b4_row4_col3 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_208b4_row5_col0 {
#   background-color: #942f03;
#   color: #f1f1f1;
# }
# #T_208b4_row5_col1 {
#   background-color: #fdc088;
#   color: #000000;
# }
# #T_208b4_row5_col2 {
#   background-color: #d54601;
#   color: #f1f1f1;
# }
# #T_208b4_row5_col3 {
#   background-color: #fff5ea;
#   color: #000000;
# }
# #T_208b4_row6_col0 {
#   background-color: #802704;
#   color: #f1f1f1;
# }
# #T_208b4_row6_col1 {
#   background-color: #fee5cb;
#   color: #000000;
# }
# #T_208b4_row6_col2 {
#   background-color: #cd4401;
#   color: #f1f1f1;
# }
# #T_208b4_row6_col3 {
#   background-color: #ffeedd;
#   color: #000000;
# }
# #T_208b4_row7_col0 {
#   background-color: #f77b28;
#   color: #f1f1f1;
# }
# #T_208b4_row7_col1 {
#   background-color: #be3f02;
#   color: #f1f1f1;
# }
# #T_208b4_row7_col2 {
#   background-color: #d34601;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_208b4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_208b4_level0_col0" class="col_heading level0 col0" >Acc</th>
#       <th id="T_208b4_level0_col1" class="col_heading level0 col1" >F1</th>
#       <th id="T_208b4_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_208b4_level0_col3" class="col_heading level0 col3" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_208b4_level0_row0" class="row_heading level0 row0" >Elastic-Net LR</th>
#       <td id="T_208b4_row0_col0" class="data row0 col0" >0.531</td>
#       <td id="T_208b4_row0_col1" class="data row0 col1" >0.445</td>
#       <td id="T_208b4_row0_col2" class="data row0 col2" >0.530</td>
#       <td id="T_208b4_row0_col3" class="data row0 col3" >0.060</td>
#     </tr>
#     <tr>
#       <th id="T_208b4_level0_row1" class="row_heading level0 row1" >RBF-SVM</th>
#       <td id="T_208b4_row1_col0" class="data row1 col0" >0.646</td>
#       <td id="T_208b4_row1_col1" class="data row1 col1" >0.000</td>
#       <td id="T_208b4_row1_col2" class="data row1 col2" >0.493</td>
#       <td id="T_208b4_row1_col3" class="data row1 col3" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_208b4_level0_row2" class="row_heading level0 row2" >Random Forest</th>
#       <td id="T_208b4_row2_col0" class="data row2 col0" >0.617</td>
#       <td id="T_208b4_row2_col1" class="data row2 col1" >0.195</td>
#       <td id="T_208b4_row2_col2" class="data row2 col2" >0.509</td>
#       <td id="T_208b4_row2_col3" class="data row2 col3" >0.020</td>
#     </tr>
#     <tr>
#       <th id="T_208b4_level0_row3" class="row_heading level0 row3" >Extra Trees</th>
#       <td id="T_208b4_row3_col0" class="data row3 col0" >0.604</td>
#       <td id="T_208b4_row3_col1" class="data row3 col1" >0.271</td>
#       <td id="T_208b4_row3_col2" class="data row3 col2" >0.515</td>
#       <td id="T_208b4_row3_col3" class="data row3 col3" >0.034</td>
#     </tr>
#     <tr>
#       <th id="T_208b4_level0_row4" class="row_heading level0 row4" >XGBoost</th>
#       <td id="T_208b4_row4_col0" class="data row4 col0" >0.621</td>
#       <td id="T_208b4_row4_col1" class="data row4 col1" >0.111</td>
#       <td id="T_208b4_row4_col2" class="data row4 col2" >0.479</td>
#       <td id="T_208b4_row4_col3" class="data row4 col3" >-0.016</td>
#     </tr>
#     <tr>
#       <th id="T_208b4_level0_row5" class="row_heading level0 row5" >LightGBM</th>
#       <td id="T_208b4_row5_col0" class="data row5 col0" >0.602</td>
#       <td id="T_208b4_row5_col1" class="data row5 col1" >0.190</td>
#       <td id="T_208b4_row5_col2" class="data row5 col2" >0.488</td>
#       <td id="T_208b4_row5_col3" class="data row5 col3" >-0.012</td>
#     </tr>
#     <tr>
#       <th id="T_208b4_level0_row6" class="row_heading level0 row6" >CatBoost</th>
#       <td id="T_208b4_row6_col0" class="data row6 col0" >0.641</td>
#       <td id="T_208b4_row6_col1" class="data row6 col1" >0.072</td>
#       <td id="T_208b4_row6_col2" class="data row6 col2" >0.500</td>
#       <td id="T_208b4_row6_col3" class="data row6 col3" >0.025</td>
#     </tr>
#     <tr>
#       <th id="T_208b4_level0_row7" class="row_heading level0 row7" >CALiBRE-AD+</th>
#       <td id="T_208b4_row7_col0" class="data row7 col0" >0.354</td>
#       <td id="T_208b4_row7_col1" class="data row7 col1" >0.523</td>
#       <td id="T_208b4_row7_col2" class="data row7 col2" >0.490</td>
#       <td id="T_208b4_row7_col3" class="data row7 col3" >0.000</td>
#     </tr>
#   </tbody>
# </table>
# <div style="background:#7d4a9e;color:white;padding:9px 16px;border-radius:8px;font-size:15px;font-weight:600;margin:8px 0;font-family:sans-serif;">📋&nbsp; TABLE V (cost-ratio sensitivity)</div>
# <style type="text/css">
# #T_a0dfc caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding: 6px 0;
#   caption-side: top;
# }
# #T_a0dfc th {
#   font-size: 12px;
# }
# #T_a0dfc td {
#   font-size: 12px;
#   text-align: center;
# }
# #T_a0dfc_row0_col0, #T_a0dfc_row1_col0 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_a0dfc_row0_col1, #T_a0dfc_row1_col1 {
#   background-color: #8784bd;
#   color: #f1f1f1;
# }
# #T_a0dfc_row0_col2 {
#   background-color: #6c55a5;
#   color: #f1f1f1;
# }
# #T_a0dfc_row0_col3 {
#   background-color: #dcdcec;
#   color: #000000;
# }
# #T_a0dfc_row1_col2 {
#   background-color: #715faa;
#   color: #f1f1f1;
# }
# #T_a0dfc_row1_col3 {
#   background-color: #e1e0ee;
#   color: #000000;
# }
# #T_a0dfc_row2_col0 {
#   background-color: #440981;
#   color: #f1f1f1;
# }
# #T_a0dfc_row2_col1, #T_a0dfc_row3_col1 {
#   background-color: #7b72b4;
#   color: #f1f1f1;
# }
# #T_a0dfc_row2_col2 {
#   background-color: #7465ad;
#   color: #f1f1f1;
# }
# #T_a0dfc_row2_col3 {
#   background-color: #e8e7f2;
#   color: #000000;
# }
# #T_a0dfc_row3_col0 {
#   background-color: #4f1d8b;
#   color: #f1f1f1;
# }
# #T_a0dfc_row3_col2 {
#   background-color: #8a86bf;
#   color: #f1f1f1;
# }
# #T_a0dfc_row3_col3 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_a0dfc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0dfc_level0_col0" class="col_heading level0 col0" >Acc</th>
#       <th id="T_a0dfc_level0_col1" class="col_heading level0 col1" >Rc</th>
#       <th id="T_a0dfc_level0_col2" class="col_heading level0 col2" >F1</th>
#       <th id="T_a0dfc_level0_col3" class="col_heading level0 col3" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0dfc_level0_row0" class="row_heading level0 row0" >1:1</th>
#       <td id="T_a0dfc_row0_col0" class="data row0 col0" >0.953</td>
#       <td id="T_a0dfc_row0_col1" class="data row0 col1" >0.924</td>
#       <td id="T_a0dfc_row0_col2" class="data row0 col2" >0.934</td>
#       <td id="T_a0dfc_row0_col3" class="data row0 col3" >0.898</td>
#     </tr>
#     <tr>
#       <th id="T_a0dfc_level0_row1" class="row_heading level0 row1" >2:1</th>
#       <td id="T_a0dfc_row1_col0" class="data row1 col0" >0.953</td>
#       <td id="T_a0dfc_row1_col1" class="data row1 col1" >0.924</td>
#       <td id="T_a0dfc_row1_col2" class="data row1 col2" >0.932</td>
#       <td id="T_a0dfc_row1_col3" class="data row1 col3" >0.896</td>
#     </tr>
#     <tr>
#       <th id="T_a0dfc_level0_row2" class="row_heading level0 row2" >5:1</th>
#       <td id="T_a0dfc_row2_col0" class="data row2 col0" >0.951</td>
#       <td id="T_a0dfc_row2_col1" class="data row2 col1" >0.928</td>
#       <td id="T_a0dfc_row2_col2" class="data row2 col2" >0.931</td>
#       <td id="T_a0dfc_row2_col3" class="data row2 col3" >0.893</td>
#     </tr>
#     <tr>
#       <th id="T_a0dfc_level0_row3" class="row_heading level0 row3" >10:1</th>
#       <td id="T_a0dfc_row3_col0" class="data row3 col0" >0.946</td>
#       <td id="T_a0dfc_row3_col1" class="data row3 col1" >0.928</td>
#       <td id="T_a0dfc_row3_col2" class="data row3 col2" >0.923</td>
#       <td id="T_a0dfc_row3_col3" class="data row3 col3" >0.881</td>
#     </tr>
#   </tbody>
# </table>
# <div style="background:#7d4a9e;color:white;padding:9px 16px;border-radius:8px;font-size:15px;font-weight:600;margin:8px 0;font-family:sans-serif;">📋&nbsp; TABLE VII (ablation)</div>
# <style type="text/css">
# #T_63566 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding: 6px 0;
#   caption-side: top;
# }
# #T_63566 th {
#   font-size: 12px;
# }
# #T_63566 td {
#   font-size: 12px;
#   text-align: center;
# }
# #T_63566_row0_col0, #T_63566_row0_col1, #T_63566_row1_col0, #T_63566_row2_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_63566_row0_col2, #T_63566_row1_col2, #T_63566_row2_col2, #T_63566_row3_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_63566_row0_col3 {
#   background-color: #005020;
#   color: #f1f1f1;
# }
# #T_63566_row1_col1, #T_63566_row2_col1, #T_63566_row3_col0, #T_63566_row3_col1 {
#   background-color: #00451c;
#   color: #f1f1f1;
# }
# #T_63566_row1_col3, #T_63566_row2_col3 {
#   background-color: #004e1f;
#   color: #f1f1f1;
# }
# #T_63566_row3_col3 {
#   background-color: #004d1f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_63566">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_63566_level0_col0" class="col_heading level0 col0" >Acc</th>
#       <th id="T_63566_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_63566_level0_col2" class="col_heading level0 col2" >Brr</th>
#       <th id="T_63566_level0_col3" class="col_heading level0 col3" >Rc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63566_level0_row0" class="row_heading level0 row0" >Best single base learner (LightGBM)</th>
#       <td id="T_63566_row0_col0" class="data row0 col0" >0.955</td>
#       <td id="T_63566_row0_col1" class="data row0 col1" >0.952</td>
#       <td id="T_63566_row0_col2" class="data row0 col2" >0.045</td>
#       <td id="T_63566_row0_col3" class="data row0 col3" >0.922</td>
#     </tr>
#     <tr>
#       <th id="T_63566_level0_row1" class="row_heading level0 row1" >+ Heterogeneous stacking (no calibration)</th>
#       <td id="T_63566_row1_col0" class="data row1 col0" >0.955</td>
#       <td id="T_63566_row1_col1" class="data row1 col1" >0.950</td>
#       <td id="T_63566_row1_col2" class="data row1 col2" >0.045</td>
#       <td id="T_63566_row1_col3" class="data row1 col3" >0.926</td>
#     </tr>
#     <tr>
#       <th id="T_63566_level0_row2" class="row_heading level0 row2" >+ Adaptive calibration (tau = 0.5)</th>
#       <td id="T_63566_row2_col0" class="data row2 col0" >0.953</td>
#       <td id="T_63566_row2_col1" class="data row2 col1" >0.948</td>
#       <td id="T_63566_row2_col2" class="data row2 col2" >0.043</td>
#       <td id="T_63566_row2_col3" class="data row2 col3" >0.924</td>
#     </tr>
#     <tr>
#       <th id="T_63566_level0_row3" class="row_heading level0 row3" >+ Cost-optimal threshold (CALiBRE-AD+)</th>
#       <td id="T_63566_row3_col0" class="data row3 col0" >0.951</td>
#       <td id="T_63566_row3_col1" class="data row3 col1" >0.948</td>
#       <td id="T_63566_row3_col2" class="data row3 col2" >0.043</td>
#       <td id="T_63566_row3_col3" class="data row3 col3" >0.928</td>
#     </tr>
#   </tbody>
# </table>
# Abstract  | Acc 0.951  Rc 0.928  AUC 0.948  Brier 0.043
# Abstract  | Acc 95% CI [0.941, 0.960]  AUC 95% CI [0.935, 0.960]
# Abstract  | Screening AUC 0.490, MCC 0.000
# Sec VII-A | mean tau = 0.163; per-fold [0.075, 0.24, 0.165, 0.205, 0.13]
# Sec VII-C | Brier raw 0.0447 -> calibrated 0.0429
# Sec V-C   | calibrator choice Full {'sigmoid': 3, 'isotonic': 2}, Screening {'sigmoid': 5}
# Fig 8     | confusion matrix [[1339, 50], [55, 705]]
# <div style="background:#2e8b57;color:white;padding:9px 16px;border-radius:8px;font-size:15px;font-weight:600;margin:8px 0;font-family:sans-serif;">✅&nbsp; Saved paper_numbers.json — everything above is reproducible from this file.</div>
